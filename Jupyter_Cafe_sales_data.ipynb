# %%
import pandas as pd
df= pd.read_csv("Cafe sales data.csv")
df.head()
# Out:
#   Transaction ID    Item  Quantity  Price Per Unit ($)  Total Spent ($)  \
# 0    TXN_1961373  Coffee       2.0                20.0             40.0
# 1    TXN_4977031    Cake       4.0                30.0            120.0
# 2    TXN_4271903  Cookie       4.0                10.0              NaN
# 3    TXN_7034554   Salad       2.0                50.0            100.0
# 4    TXN_3160411  Coffee       2.0                20.0             40.0
#
#    Payment Method  Location Transaction Date
# 0     Credit Card  Takeaway       08 09 2023
# 1            Cash  In-store       16 05 2023
# 2     Credit Card  In-store       19 07 2023
# 3             NaN       NaN       27 04 2023
# 4  Digital Wallet  In-store       11 06 2023

# %%
df.shape
# Out:
# (10000, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Transaction ID      10000 non-null  object
#  1   Item                9323 non-null   object
#  2   Quantity            9521 non-null   float64
#  3   Price Per Unit ($)  9646 non-null   float64
#  4   Total Spent ($)     9670 non-null   float64
#  5   Payment Method      6822 non-null   object
#  6   Location            6039 non-null   object
#  7   Transaction Date    9540 non-null   object
# dtypes: float64(3), object(5)
# memory usage: 625.1+ KB

# %%
df.isnull().sum()
# Out:
# Transaction ID           0
# Item                   677
# Quantity               479
# Price Per Unit ($)     354
# Total Spent ($)        330
# Payment Method        3178
# Location              3961
# Transaction Date       460
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Transaction Date"]=pd.to_datetime(df["Transaction Date"],errors="coerce")

# %%
text_cols=df.select_dtypes(include="object").columns

# %%
df["Item"]=df["Item"].fillna("Unknown")

# %%
df["Quantity"]=df["Quantity"].fillna(df["Quantity"].median())

# %%
df["Price Per Unit ($)"]=df["Price Per Unit ($)"].fillna(df["Price Per Unit ($)"].median())

# %%
df["Payment Method"]=df["Payment Method"].fillna("Unknown")

# %%
df["Location"]=df["Location"].fillna(df["Location"].mode()[0])

# %%
df["Total Spent ($)"]=df["Quantity"]*df["Price Per Unit ($)"]

# %%
df[["Quantity", "Price Per Unit ($)", "Total Spent ($)"]].head(10)
# Out:
#    Quantity  Price Per Unit ($)  Total Spent ($)
# 0       2.0                20.0             40.0
# 1       4.0                30.0            120.0
# 2       4.0                10.0             40.0
# 3       2.0                50.0            100.0
# 4       2.0                20.0             40.0
# 5       5.0                40.0            200.0
# 6       3.0                30.0             90.0
# 7       4.0                40.0            160.0
# 8       5.0                30.0            150.0
# 9       5.0                40.0            200.0

# %%
df["Transaction Date"] = df["Transaction Date"].fillna(df["Transaction Date"].median())

# %%
df.isnull().sum()
# Out:
# Transaction ID        0
# Item                  0
# Quantity              0
# Price Per Unit ($)    0
# Total Spent ($)       0
# Payment Method        0
# Location              0
# Transaction Date      0
# dtype: int64

# %%
text_cols=df.select_dtypes(include="object").columns
for col in text_cols:
    df[col]=df[col].str.strip().str.title()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[["Item"]].head(10)
# Out:
#        Item
# 0    Coffee
# 1      Cake
# 2    Cookie
# 3     Salad
# 4    Coffee
# 5  Smoothie
# 6   Unknown
# 7  Sandwich
# 8   Unknown
# 9  Sandwich

# %%
df.to_csv("Cafe sales data.csv",index=False)

# %%
from google.colab import files
files.download("Cafe sales data.csv")

# %%
df["Item"]=df["Item"].str.replace("error","Unknown",case=False)

# %%
df[["Item"]].head(20)
# Out:
#         Item
# 0     Coffee
# 1       Cake
# 2     Cookie
# 3      Salad
# 4     Coffee
# 5   Smoothie
# 6    Unknown
# 7   Sandwich
# 8    Unknown
# 9   Sandwich
# 10     Salad
# 11  Sandwich
# 12  Sandwich
# 13    Cookie
# 14   Unknown
# 15     Salad
# 16  Sandwich
# 17     Juice
# 18      Cake
# 19     Juice

# %%
df.to_csv("Cafe sales data.csv",index=False)

# %%
from google.colab import files
files.download("Cafe sales data.csv")
